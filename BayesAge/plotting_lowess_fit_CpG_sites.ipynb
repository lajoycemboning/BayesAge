# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
#import numpy as np
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
from matplotlib.lines import Line2D

#import

# %%
os.getcwd()
# Out:
# '/'

# %%
df = pd.read_csv("/Users/lajoyce/Documents/genomics/epiage/BayesAge/data/sample_458_age.csv", sep="\t", low_memory=False)

# %%
cpgs_8 = ['chr5_16179182', 'chr5_16179171', 'chr7_8442747', 'chr19_18233128', 'chr9_133609524', 'chr5_16179195', 'chr19_18233106', 'chr19_18233140']

# %%
y = df["chr5_16179182"].values.flatten()
y2 = df["chr5_16179171"].values.flatten()
y3 = df["chr7_8442747"].values.flatten()
y4 = df["chr19_18233128"].values.flatten()
y5 = df["chr9_133609524"].values.flatten()
y6 = df["chr5_16179195"].values.flatten()
y7 = df["chr19_18233106"].values.flatten()
y8 = df["chr19_18233140"].values.flatten()

# %%
x = df["Age"].values.flatten()

# %%
tau = 0.9

# %%
predicted_methylation = lowess(y, x, frac = tau)
predicted_meth_2 = lowess(y2, x, frac = tau)
predicted_meth_3 = lowess(y3, x, frac = tau)
predicted_meth_4 = lowess(y4, x, frac = tau)
predicted_meth_5 = lowess(y5, x, frac = tau)
predicted_meth_6 = lowess(y6, x, frac = tau)
predicted_meth_7 = lowess(y7, x, frac = tau)
predicted_meth_8 = lowess(y8, x, frac = tau)

# %%
fig = plt.figure(figsize=(25, 25))

#fig.subplots_adjust(hspace=50, top=50)

fig.subplots_adjust(hspace = 5, top=1)

#fig.suptitle("Subject 130010 Top 16 CpG Sites LOWESS Fitting Using Tau = 0.7", fontname = "Sathu", fontsize=25)

sub1 = fig.add_subplot(4,2,1)
sub1.set_title("chr5_16179182", fontname = "Sathu", fontsize = 20)
sub1.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub1.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
sub1.scatter(x, y, color = "steelblue", label = "Observed Methylation")
#sub1.plot(predicted_methylation[:,0], predicted_methylation[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line1 = Line2D(predicted_methylation[:,0], predicted_methylation[:,1], color = "palevioletred", linewidth=3)
sub1.add_line(line1)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
sub1.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")


sub2 = fig.add_subplot(4,2,2) # facecolor = "lightgrey")
sub2.set_title("chr5_16179171", fontname = "Sathu", fontsize = 20)
sub2.scatter(x, y2, color = "steelblue", label = "Observed Methylation")
#sub2.plot(predicted_meth_2[:,0], predicted_meth_2[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line2 = Line2D(predicted_meth_2[:,0], predicted_meth_2[:,1], color = "palevioletred", linewidth=3)
sub2.add_line(line2)
sub2.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub2.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
sub2.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub3 = fig.add_subplot(4,2,3)
sub3.set_title("chr7_8442747", fontname = "Sathu", fontsize = 20)
sub3.scatter(x, y3, color = "steelblue",  label = "Observed Methylation")
#sub3.plot(predicted_meth_3[:,0], predicted_meth_3[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line3 = Line2D(predicted_meth_3[:,0], predicted_meth_3[:,1], color = "palevioletred", linewidth=3)
sub3.add_line(line3)
sub3.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub3.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y3, 1)
p = np.poly1d(z)
sub3.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub4 = fig.add_subplot(4,2,4)
sub4.set_title("chr19_18233128", fontname = "Sathu", fontsize = 20)
sub4.scatter(x, y4, color = "steelblue",  label = "Observed Methylation")
#sub4.plot(predicted_meth_4[:,0], predicted_meth_4[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line4 = Line2D(predicted_meth_4[:,0], predicted_meth_4[:,1], color = "palevioletred", linewidth=3)
sub4.add_line(line4)
sub4.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub4.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y4, 1)
p = np.poly1d(z)
sub4.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub5 = fig.add_subplot(4,2,5)
sub5.set_title("chr9_133609524", fontname = "Sathu", fontsize = 20)
sub5.scatter(x, y5, color = "steelblue", label = "Observed Methylation")
#sub5.plot(predicted_meth_5[:,0], predicted_meth_5[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line5 = Line2D(predicted_meth_5[:,0], predicted_meth_5[:,1], color = "palevioletred", linewidth=3)
sub5.add_line(line5)
sub5.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub5.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y5, 1)
p = np.poly1d(z)
sub5.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub6 = fig.add_subplot(426)
sub6.set_title("chr5_16179195", fontname = "Sathu", fontsize = 20)
sub6.scatter(x, y6, color = "steelblue", label = "Observed Methylation")
#sub6.plot(predicted_meth_6[:,0], predicted_meth_6[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line6 = Line2D(predicted_meth_6[:,0], predicted_meth_6[:,1], color = "palevioletred", linewidth=3)
sub6.add_line(line6)
sub6.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub6.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20) 
z = np.polyfit(x, y6, 1)
p = np.poly1d(z)
sub6.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub7 = fig.add_subplot(427)
sub7.set_title("chr19_18233106", fontname = "Sathu", fontsize = 20)
sub7.scatter(x, y7, color = "steelblue", label = "Observed Methylation")
#sub7.plot(predicted_meth_7[:,0], predicted_meth_7[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line7=Line2D(predicted_meth_7[:, 0], predicted_meth_7[:,1], color = "palevioletred", linewidth=3)
sub7.add_line(line7)
sub7.set_xlabel("Real Age", fontname = "Times", fontsize=20)
sub7.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y7, 1)
p = np.poly1d(z)
sub7.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub8 = fig.add_subplot(428)
sub8.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub8.scatter(x, y8, color = "steelblue", label = "Observed Methylation")
#sub8.plot(predicted_meth_8[:,0], predicted_meth_8[:, 1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line8 = Line2D(predicted_meth_8[:, 0], predicted_meth_8[:, 1], color="palevioletred", linewidth=3)
sub8.add_line(line8)
sub8.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub8.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
z = np.polyfit(x, y8, 1)
p = np.poly1d(z)
sub8.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

# Adjust the size of x and y axis numbers (tick labels)
for sub in [sub1, sub2, sub3, sub4, sub5, sub6, sub7, sub8]: # sub9, sub10, sub11, sub12, sub13, sub14, sub15, sub16]:
    sub.set_xlabel("Real Age", fontname="Times New Roman", fontsize=25)
    sub.set_ylabel("Methylation Level", fontname="Times New Roman", fontsize=25)
    sub.tick_params(axis='x', labelsize=16)  # Adjust x-axis tick label size
    sub.tick_params(axis='y', labelsize=16)  # Adjust y-axis tick label size

#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
fig.tight_layout()

plt.tight_layout()

plt.show()

#fig.savefig("/Users/lajoyce/Documents/genomics/epiage/BayesAge/reviews/tau_analysis/plots/top_8_cpgs_tau_fitting_point_nine.png", dpi = 300) # bbox_inches = "tight_layout")

# %% [markdown]
# ## One CpG Site with different Tau Values

# %%
y8 = df["chr19_18233140"].values.flatten()

# %%
predicted_methylation = lowess(y8, x, frac = 0.1)
predicted_meth_2 = lowess(y8, x, frac = 0.3)
predicted_meth_3 = lowess(y8, x, frac = 0.5)
predicted_meth_4 = lowess(y8, x, frac = 0.7)
predicted_meth_5 = lowess(y8, x, frac = 0.9)
predicted_meth_6 = lowess(y8, x, frac = 1.0)

# %%
fig = plt.figure(figsize=(25, 25))

#fig.subplots_adjust(hspace=50, top=50)

fig.subplots_adjust(hspace = 5, top=1)

#fig.suptitle("Subject 130010 Top 16 CpG Sites LOWESS Fitting Using Tau = 0.7", fontname = "Sathu", fontsize=25)

sub1 = fig.add_subplot(3,2,1)
sub1.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub1.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub1.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
sub1.scatter(x, y8, color = "steelblue", label = "Observed Methylation")
#sub1.plot(predicted_methylation[:,0], predicted_methylation[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line1 = Line2D(predicted_methylation[:,0], predicted_methylation[:,1], color = "palevioletred", linewidth=3)
sub1.add_line(line1)
#z = np.polyfit(x, y, 1)
#p = np.poly1d(z)
#sub1.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")


sub2 = fig.add_subplot(3,2,2) # facecolor = "lightgrey")
sub2.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub2.scatter(x, y8, color = "steelblue", label = "Observed Methylation")
#sub2.plot(predicted_meth_2[:,0], predicted_meth_2[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line2 = Line2D(predicted_meth_2[:,0], predicted_meth_2[:,1], color = "palevioletred", linewidth=3)
sub2.add_line(line2)
sub2.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub2.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
#z = np.polyfit(x, y2, 1)
#p = np.poly1d(z)
#sub2.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub3 = fig.add_subplot(3,2,3)
sub3.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub3.scatter(x, y8, color = "steelblue",  label = "Observed Methylation")
#sub3.plot(predicted_meth_3[:,0], predicted_meth_3[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line3 = Line2D(predicted_meth_3[:,0], predicted_meth_3[:,1], color = "palevioletred", linewidth=3)
sub3.add_line(line3)
sub3.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub3.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
#z = np.polyfit(x, y8, 1)
#p = np.poly1d(z)
#sub3.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub4 = fig.add_subplot(3,2,4)
sub4.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub4.scatter(x, y8, color = "steelblue",  label = "Observed Methylation")
#sub4.plot(predicted_meth_4[:,0], predicted_meth_4[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line4 = Line2D(predicted_meth_4[:,0], predicted_meth_4[:,1], color = "palevioletred", linewidth=3)
sub4.add_line(line4)
sub4.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub4.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
#z = np.polyfit(x, y4, 1)
#p = np.poly1d(z)
#sub4.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub5 = fig.add_subplot(3,2,5)
sub5.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub5.scatter(x, y8, color = "steelblue", label = "Observed Methylation")
#sub5.plot(predicted_meth_5[:,0], predicted_meth_5[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line5 = Line2D(predicted_meth_5[:,0], predicted_meth_5[:,1], color = "palevioletred", linewidth=3)
sub5.add_line(line5)
sub5.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub5.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20)
#z = np.polyfit(x, y5, 1)
#p = np.poly1d(z)
#sub5.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

sub6 = fig.add_subplot(326)
sub6.set_title("chr19_18233140", fontname = "Sathu", fontsize = 20)
sub6.scatter(x, y8, color = "steelblue", label = "Observed Methylation")
#sub6.plot(predicted_meth_6[:,0], predicted_meth_6[:,1], color = "palevioletred", label = "LOWESS Predicted Methylation")
line6 = Line2D(predicted_meth_6[:,0], predicted_meth_6[:,1], color = "palevioletred", linewidth=3)
sub6.add_line(line6)
sub6.set_xlabel("Real Age", fontname = "Times New Roman", fontsize=20)
sub6.set_ylabel("Methylation Level", fontname = "Times New Roman", fontsize=20) 
#z = np.polyfit(x, y6, 1)
#p = np.poly1d(z)
#sub6.plot(x, p(x), color="indigo", linewidth=3, linestyle="--")

# Adjust the size of x and y axis numbers (tick labels)
for sub in [sub1, sub2, sub3, sub4, sub5, sub6]: # sub7, sub8]: # sub9, sub10, sub11, sub12, sub13, sub14, sub15, sub16]:
    sub.set_xlabel("Real Age", fontname="Times New Roman", fontsize=25)
    sub.set_ylabel("Methylation Level", fontname="Times New Roman", fontsize=25)
    sub.tick_params(axis='x', labelsize=16)  # Adjust x-axis tick label size
    sub.tick_params(axis='y', labelsize=16)  # Adjust y-axis tick label size

#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
fig.tight_layout()

plt.tight_layout()

plt.show()

#fig.savefig("/Users/lajoyce/Documents/genomics/epiage/BayesAge/reviews/tau_analysis/plots/one_cpg_site_different_taus.png", dpi = 300) # bbox_inches = "tight_layout")
